# %% [markdown]
# <a href="https://colab.research.google.com/github/JLettsSJU931/Machine-Learning-FA26/blob/main/HW1/JL_HW1_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **James Letts Homework 1 Analysis**
# ######8/31/2026
# ----
# #Analysis Questions
#
# ###1.
# * Q: Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
# * A: Before doing anything, make sure you have a Github repository ready with a folder you wish to put the assignment in. The first step is to write the assignment and code into colab through your browser. Then, go to file and hit "save a copy to github", select the repository, and add the folders name that you wish to save the file into with a /. After this, hit save and it will now be present in the github repository. To do the opposite, download the raw file of the colab notebook from github and simply go to file to hit "upload notebook". Then simply click the raw data you just saved and open it in colab.
#
# ###2.
# * Q: Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
# * A: When I executed the code tidbits in the notebooks, none of them needed any edits from what I could see, and everything executed immediately after clicking the button.
#
# ###3.
# * Q: Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
# * A: I created my machine learning repository by opening github, signing into my school account, and manuvering towards repositories to hit "new". I then cloned this repository to VScode by hitting "code" and copying the .git url, pasting it into VScode.
#
# ###4.
# * Q: Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
# * A: These python data structures are the foundation of the programs we will use in the rest of the class, and thus if we do not know baseline python then we will not be able to function much of anything in future.
