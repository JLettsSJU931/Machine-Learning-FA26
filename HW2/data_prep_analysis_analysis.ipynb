# %% [markdown]
# <a href="https://colab.research.google.com/github/JLettsSJU931/Machine-Learning-FA26/blob/main/HW2/data_prep_analysis_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   **Question**: What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets?
# **Answer**: I did not notice any particular challenges loading the dataset, however the process of examining did take a bit of getting used to, with many of these programs and plugins being thing I haven't used before.
# 2.   **Question**: How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose? **Answer**: I used the pandas funtion "isna()" to find null values, with an added "sum()" to detect the fact that "encryption_used" was missing 1966 entries. I then used "fillna()" to fill the null values, which worked perfectly.
# 3.   **Question**: Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing steps. **Answer**: These two plugins work by grouping column specific transformations and sequential steps into single, cohesive objects that can fit only into the training data.
# 4.   **Question**: Based on your correlation matrix and heatmap, which features show the strongest relationships with the target variable (attack_detected), and what operational insights do these relationships reveal? **Answer**: The correlational matrix as well as the heatmap showed me that the three variables that have the strongest correlation to the attack_detected attribute were login_attempts, ip_reputation_score, and failed_logins. The connection between failed_logins/login_attempts and attack_detected shows how hackers can use brute force repetative login attempts to try to get into an account, and that the more they try the more likely they are to succecced. The connecting with IP, on the other hand, shows a correlation between your IP being potentially leaked and an attack being done on your device, which does make sense.
